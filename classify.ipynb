# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.models import sequential 
from keras.preprocessing import image
import glob
import matplotlib.image as mpimg
# %matplotlib inline
import os
import pandas as pd
import shutil
from tqdm import tqdm

# %%
train_data = pd.read_csv("covid_noura-dataset/Chest_xray_Corona_Metadata.csv")
# summary = pd.read_csv("../input/coronahack-chest-xraydataset/Chest_xray_Corona_dataset_Summary.csv")
train_data.head()
# Out:
#    Unnamed: 0   X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0           0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1           1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2           2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3           3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4           4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
#COVID-19
to_train_pnemonia = 'covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia'
source_train = 'covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train'
move_train_pnemonia = train_data[train_data.Label == 'Pnemonia']['X_ray_image_name'].values
for i in tqdm(move_train_pnemonia):
    path = os.path.join(source_train,i)
    print(path)
    # shutil.copy(path,to_train_pnemonia)
# Out:
#  20%|██        | 869/4334 [00:00<00:00, 8682.82it/s]covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person101_virus_188.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person101_virus_187.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1019_virus_1708.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1019_virus_1707.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1019_bacteria_2950.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1018_virus_1706.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1018_bacteria_2949.jpeg
# covid_noura-dataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/person1017_bacteria_2948.jpeg
# ...

# %%
   
# #Normal
# to_train_normal = '../working/train/Normal/'
# move_train_normal = train_data[train_data.Label == 'Normal']['X_ray_image_name'].values
# for i in tqdm(move_train_normal):
#     path = os.path.join(source_train,i)
#     shutil.copy(path,to_train_normal)
​
df = pd.read_csv("/home/mahmoud-alzoubi/multiclass_classification/Chest_xray_Corona_Metadata.csv")
# summary = pd.read_csv("../input/coronahack-chest-xraydataset/Chest_xray_Corona_dataset_Summary.csv")
df.head()
​
train_data = df[df['Dataset_type'] == 'TRAIN']
test_data = df[df['Dataset_type'] == 'TEST']
# test_data
​
def create_directory():
    try:
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Normal')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Normal')
    except:
        pass
​
​
test_data[test_data.Label == 'Pnemonia'].head()
​
​
create_directory()
​
#Normal
train_normal = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Normal'
move_train_normal = train_data[train_data.Label == 'Normal']['X_ray_image_name'].values
for i in move_train_normal:
    path = os.path.join(source_train,i)
    shutil.copy(path,train_normal)
​
​
​
# #COVID
# train_pnemonia = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia'
# source_train = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train"
# move_train_pnemonia = train_data[ train_data['Label'] == 'Pnemonia']['X_ray_image_name'].values
# for i in move_train_pnemonia:
#     path = os.path.join(source_train,i)
#     shutil.copy(path,train_pnemonia)
    
    
​
#for test data
​
#COVID
test_pnemonia = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia'
source_test = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test"
move_test_pnemonia = test_data[test_data['Label'] == 'Pnemonia']['X_ray_image_name'].values
                               
for i in move_test_pnemonia:
    
    path2 = os.path.join(source_test, i)
    shutil.copy(path2, test_pnemonia)
​
test_normal = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Normal/'
move_test_normal = test_data[test_data.Label == 'Normal']['X_ray_image_name'].values
for i in move_test_normal:
    path3 = os.path.join(source_test, i)
    shutil.copy(path3, test_normal)
​
​
def create_sub_directory():
    try:
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/becteria')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/smoking')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia/Virus')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia/becteria')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia/smoking')
    except:
        pass
​
create_sub_directory()
​
​
#bacteria
train_pnemonia_bacteria = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/becteria'
source_train_bacteria = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia"
move_train_pnemonia_bacteria = train_data[train_data['Label_1_Virus_category'] == 'bacteria']['X_ray_image_name'].values
print(move_train_pnemonia_bacteria)
for i in move_train_pnemonia_bacteria:
    path = os.path.join(source_train_bacteria,i)
    shutil.copy(path,train_pnemonia_bacteria)
​
​
#Virus
train_pnemonia_virus = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus'
source_train_virus = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia"
move_train_pnemonia_virus = train_data[train_data['Label_1_Virus_category'] == 'Virus']['X_ray_image_name'].values
print(move_train_pnemonia_virus)
for i in move_train_pnemonia_virus:
    path = os.path.join(source_train_virus,i)
    shutil.copy(path,train_pnemonia_virus) 
    
    
​
# #smoking
# train_pnemonia_smoking = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/smoking'
# source_train_smoking = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia"
# move_train_pnemonia_smoking = train_data[train_data['Label_1_Virus_category'] == 'Stress-Smoking']['X_ray_image_name'].values
# print(move_train_pnemonia_smoking)
# for i in move_train_pnemonia_smoking:
#     path = os.path.join(source_train_smoking,i)
#     shutil.copy(path,train_pnemonia_smoking)
​
​
def create_sub_virus_directory():
    try:
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus/covid')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus/sars')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia/Virus/covid')
        os.makedirs('/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test/Pnemonia/Virus/sars')
    except:
        pass
​
create_sub_virus_directory()
​
#covid
train_pnemonia_covid = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus/covid'
source_train_covid = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus"
move_train_pnemonia_covid = train_data[train_data['Label_2_Virus_category'] == 'COVID-19']['X_ray_image_name'].values
# print(move_train_pnemonia_covid)
for i in move_train_pnemonia_covid:
    path = os.path.join(source_train_covid,i)
    shutil.copy(path,train_pnemonia_covid)
​
#sars
train_pnemonia_sars = '/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus/sars'
source_train_sars = "/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/Virus"
move_train_pnemonia_sars = train_data[train_data['Label_2_Virus_category'] == 'SARS']['X_ray_image_name'].values
# print(move_train_pnemonia_sars)
for i in move_train_pnemonia_sars:
    path = os.path.join(source_train_sars,i)
    shutil.copy(path,train_pnemonia_sars)
​
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
import keras 
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten
from keras.models import Sequential
from keras.preprocessing import image
​
​
img = image.load_img("/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train/Pnemonia/person12_bacteria_46.jpeg")
plt.imshow(img)
​
train_datagen = image.ImageDataGenerator(rescale = 1/255, rotation_range = 0.2, 
                              zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)
test_datagen = image.ImageDataGenerator(rescale=1/255) 
​
​
train_gen = train_datagen.flow_from_directory("/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train", target_size = (200,200),
                                             batch_size = 50, class_mode = 'binary', 
                                              subset= 'training')
valid_gen = train_datagen.flow_from_directory("/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train", target_size = (200,200),
                                             batch_size = 50, class_mode = 'binary', 
                                              subset= 'validation')
test_gen = test_datagen.flow_from_directory("/home/mahmoud-alzoubi/multiclass_classification/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/test", target_size = (200,200),
                                             batch_size = 50, class_mode = 'binary')
